# %% [markdown]
# ## Definitions

# %%
import requests
import pandas as pd
import os
import pdb
from dotenv import load_dotenv
import math
from tqdm import tqdm
import time

load_dotenv()
API_KEY = os.getenv('SCOPUS_API_KEY')

# %% [markdown]
# ## ORCIDs

# %%
def scopus_json_to_df(d):
    results = d['search-results']
    if 'entry' in results:
        return pd.json_normalize(results['entry'])
    else:
        pdb.set_trace()
        ## TODO: Inform about missing 'entry'
        return pd.DataFrame()
    
def perform_single_scopus_request(start, query, api_key, count_per_page):
    url_template = 'https://api.elsevier.com/content/search/scopus?start={start}&count={count_per_page}&query={query}&apiKey={api_key}&httpAccept=application/json'
    try:
        r = requests.get(url_template.format(start=start,query=query,api_key=api_key,count_per_page=count_per_page))
        if r.status_code == 200:
            return r
        else:
            print(f'Query: "{query}" returned wrong status code. Status code: {r.status_code} Reason: {str(r.reason)}')
    except Exception as e:
            print(f'Query: "{query}" failed. Reason: {str(e)}')
            
def request_scopus_search(query, api_key, count_per_page=25):
    r = perform_single_scopus_request(0, query, api_key, count_per_page)
    if r is not None:
        d = r.json()
        total_results = int(d['search-results']['opensearch:totalResults'])
        if total_results == 0:
            return pd.DataFrame() # If no results,send empty DF

        elif total_results > 0 and total_results <= count_per_page:
            return scopus_json_to_df(d)

        elif total_results > count_per_page:
            page_ds = [d]

            for page_start in range(count_per_page,total_results,count_per_page):
                r = perform_single_scopus_request(page_start, query, api_key, count_per_page)
                page_ds.append(r.json())

            alldf = pd.concat([scopus_json_to_df(page_d) for page_d in page_ds])

            ## TODO: finish paging
            return alldf
        else:
            print(f'Total results should NEVER be negative. Query: "{query}"')
            pdb.set_trace()

def request_scopus_orcid(orcid, api_key):
    return request_scopus_search(f'orcid({orcid})', api_key).assign(searched_orcid=orcid,timestamp=pd.Timestamp.now())

def search_all_orcids(orcids, api_key):
    dfs = []
    no_results = []
    for orcid in tqdm(orcids):
        time.sleep(.5)
        df = request_scopus_orcid(orcid, api_key)
        if not df.empty:
            dfs.append(df)
        else:
            no_results.append(orcid)
    return pd.concat(dfs), no_results

orcids = pd.read_excel('input/list_orcid.xls',header=None)[0].rename('orcids')

df_orcids, no_results_orcids = search_all_orcids(orcids, API_KEY)
df_orcids
# Out:
# 100%|██████████| 489/489 [23:24<00:00,  2.87s/it]
#     @_fa                                               link  \
# 0   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 0   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 3   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# ..   ...                                                ...
# 8   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 9   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 10  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 11  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 12  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                             prism:url          dc:identifier  \
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85122308989
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85133719027
# 1   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85124376364
# 2   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85102934268
# 3   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85094640057
# ..                                                ...                    ...
# 8   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84943534174
# 9   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84914814472
# 10  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84877786141
# 11  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84868247092
# 12  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:79957730105
#
#                    eid                                           dc:title  \
# 0   2-s2.0-85122308989  The effect of moisture, nutrients and disturba...
# 0   2-s2.0-85133719027  Grafting of silver nanospheres and nanoplates ...
# 1   2-s2.0-85124376364  Plasma treatment of PTFE at elevated temperatu...
# 2   2-s2.0-85102934268  Grafting of Metal Nanoparticles with Specific ...
# 3   2-s2.0-85094640057  Photochemical preparation of silver colloids i...
# ..                 ...                                                ...
# 8   2-s2.0-84943534174  Effects of long-term drainage on microbial com...
# 9   2-s2.0-84914814472  Microbial community composition and in silico ...
# 10  2-s2.0-84877786141  Methane Emissions and Methanogenic Archaea on ...
# 11  2-s2.0-84868247092  Vegetation and carbon gas dynamics under a cha...
# 12  2-s2.0-79957730105  Effect of peat re-wetting on carbon and nutrie...
#
#        dc:creator           prism:publicationName prism:issn prism:eIssn  ...  \
# 0   Bartušková A.              Functional Ecology   02698463    13652435  ...
# 0   Reznickova A.                          Vacuum   0042207X         NaN  ...
# 1   Reznickova A.  Materials Today Communications        NaN    23524928  ...
# 2    Lacmanová V.                  Chemicke Listy   00092770    12137103  ...
# 3       Kvitek O.                        Coatings        NaN    20796412  ...
# ..            ...                             ...        ...         ...  ...
# 8     Urbanová Z.   Soil Biology and Biochemistry   00380717         NaN  ...
# 9     Urbanová Z.       FEMS Microbiology Ecology   01686496    15746941  ...
# 10    Urbanová Z.                      Ecosystems   14329840    14350629  ...
# 11    Urbanová Z.     Plant Ecology and Diversity   17550874    17551668  ...
# 12    Urbanová Z.          Ecological Engineering   09258574         NaN  ...
#
#    openaccess openaccessFlag       searched_orcid                  timestamp  \
# 0           0          False  0000-0001-9550-4217 2022-09-08 11:58:16.136977
# 0           0          False  0000-0001-8517-7785 2022-09-08 11:58:21.208566
# 1           0          False  0000-0001-8517-7785 2022-09-08 11:58:21.208566
# 2           0          False  0000-0001-8517-7785 2022-09-08 11:58:21.208566
# 3           1           True  0000-0001-8517-7785 2022-09-08 11:58:21.208566
# ..        ...            ...                  ...                        ...
# 8           0          False  0000-0002-0742-3933 2022-09-08 12:21:37.700192
# 9           1           True  0000-0002-0742-3933 2022-09-08 12:21:37.700192
# 10          0          False  0000-0002-0742-3933 2022-09-08 12:21:37.700192
# 11          0          False  0000-0002-0742-3933 2022-09-08 12:21:37.700192
# 12          0          False  0000-0002-0742-3933 2022-09-08 12:21:37.700192
#
#                   pii article-number  \
# 0                 NaN            NaN
# 0   S0042207X2200392X         111268
# 1   S2352492822001301         103254
# 2                 NaN            NaN
# 3                 NaN           1046
# ..                ...            ...
# 8   S0038071715003454            NaN
# 9                 NaN            NaN
# 10                NaN            NaN
# 11                NaN            NaN
# 12  S092585741000220X            NaN
#
#                                      freetoread.value  \
# 0                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'$': 'all'}, {'$': 'publisherfullgold'}, {'$...
# ..                                                ...
# 8                                                 NaN
# 9         [{'$': 'all'}, {'$': 'publisherfree2read'}]
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
#
#                                 freetoreadLabel.value prism:isbn pubmed-id
# 0                                                 NaN        NaN       NaN
# 0                                                 NaN        NaN       NaN
# 1                                                 NaN        NaN       NaN
# 2                                                 NaN        NaN       NaN
# 3   [{'$': 'All Open Access'}, {'$': 'Gold'}, {'$'...        NaN       NaN
# ..                                                ...        ...       ...
# 8                                                 NaN        NaN       NaN
# 9         [{'$': 'All Open Access'}, {'$': 'Bronze'}]        NaN  25195805
# 10                                                NaN        NaN       NaN
# 11                                                NaN        NaN       NaN
# 12                                                NaN        NaN       NaN
#
# [15561 rows x 32 columns]

# %% [markdown]
# ### Saving output

# %%
df_orcids.to_csv('output/publications_orcids.csv')

pd.Series(no_results_orcids).to_csv('output/no_results_orcids.csv',index=False)

# %%
df_orcids.shape
# Out:
# (15561, 32)

# %% [markdown]
# ## Author IDs

# %%
def request_scopus_authorid(author_id, api_key):
    return request_scopus_search(f'au-id({author_id})', api_key).assign(searched_authorid=author_id,timestamp=pd.Timestamp.now())

def search_all_authorids(author_ids, api_key):
    dfs = []
    no_results = []
    for author_id in tqdm(author_ids):
        time.sleep(.5)
        df = request_scopus_authorid(author_id, api_key)
        if not df.empty:
            dfs.append(df)
        else:
            no_results.append(author_id)
    
    return pd.concat(dfs), no_results

author_ids = pd.read_excel('input/list_scopusid.xls',header=None)[0].rename('scopus_ids')
df_author_ids, no_results_author_ids = search_all_authorids(author_ids, API_KEY)
df_author_ids
# Out:
# 100%|██████████| 214/214 [12:10<00:00,  3.41s/it]
#     @_fa                                               link  \
# 0   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 0   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 3   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# ..   ...                                                ...
# 5   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 6   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 7   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 8   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 9   true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                             prism:url          dc:identifier  \
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:76049088350
# 0   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85133719027
# 1   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85124376364
# 2   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85102934268
# 3   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85094640057
# ..                                                ...                    ...
# 5   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84955588914
# 6   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84874198460
# 7   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:84892200599
# 8   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:79951687221
# 9   https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:77955664473
#
#                    eid                                           dc:title  \
# 0   2-s2.0-76049088350  Maximilianus wietrowsky SJ - His fate in the l...
# 0   2-s2.0-85133719027  Grafting of silver nanospheres and nanoplates ...
# 1   2-s2.0-85124376364  Plasma treatment of PTFE at elevated temperatu...
# 2   2-s2.0-85102934268  Grafting of Metal Nanoparticles with Specific ...
# 3   2-s2.0-85094640057  Photochemical preparation of silver colloids i...
# ..                 ...                                                ...
# 5   2-s2.0-84955588914  Victims’ Responses to Stalking: An Examination...
# 6   2-s2.0-84874198460  Does Cultural Context Affect the Association B...
# 7   2-s2.0-84892200599                                     Czech Republic
# 8   2-s2.0-79951687221  Reporting to the police as a response to intim...
# 9   2-s2.0-77955664473  Official crime statistics and survey data: Com...
#
#        dc:creator                              prism:publicationName  \
# 0      Bočková A.                                  Listy Filologicke
# 0   Reznickova A.                                             Vacuum
# 1   Reznickova A.                     Materials Today Communications
# 2    Lacmanová V.                                     Chemicke Listy
# 3       Kvitek O.                                           Coatings
# ..            ...                                                ...
# 5       Podaná Z.                  Journal of Interpersonal Violence
# 6       Podaná Z.           Journal of Contemporary Criminal Justice
# 7     Burianek J.  Juvenile Delinquency in Europe and Beyond: Res...
# 8       Podaná Z.                               Sociologicky Casopis
# 9      Enzmann D.   European Journal on Criminal Policy and Research
#
#    prism:issn prism:volume  ...                  timestamp  \
# 0    00244457          132  ... 2022-09-08 12:32:23.127589
# 0    0042207X          203  ... 2022-09-08 12:32:27.933472
# 1         NaN           31  ... 2022-09-08 12:32:27.933472
# 2    00092770          115  ... 2022-09-08 12:32:27.933472
# 3         NaN           10  ... 2022-09-08 12:32:27.933472
# ..        ...          ...  ...                        ...
# 5    08862605           31  ... 2022-09-08 12:44:32.880163
# 6    10439862           29  ... 2022-09-08 12:44:32.880163
# 7         NaN          NaN  ... 2022-09-08 12:44:32.880163
# 8    00380288           46  ... 2022-09-08 12:44:32.880163
# 9    09281371           16  ... 2022-09-08 12:44:32.880163
#
#                        prism:doi                pii  \
# 0                            NaN                NaN
# 0   10.1016/j.vacuum.2022.111268  S0042207X2200392X
# 1   10.1016/j.mtcomm.2022.103254  S2352492822001301
# 2                            NaN                NaN
# 3       10.3390/coatings10111046                NaN
# ..                           ...                ...
# 5       10.1177/0886260514556764                NaN
# 6       10.1177/1043986212471181                NaN
# 7   10.1007/978-0-387-95982-5_21                NaN
# 8                            NaN                NaN
# 9      10.1007/s10610-010-9121-z                NaN
#
#                                           affiliation article-number  \
# 0                                                 NaN            NaN
# 0   [{'@_fa': 'true', 'affilname': 'University of ...         111268
# 1   [{'@_fa': 'true', 'affilname': 'University of ...         103254
# 2   [{'@_fa': 'true', 'affilname': 'University of ...            NaN
# 3   [{'@_fa': 'true', 'affilname': 'University of ...           1046
# ..                                                ...            ...
# 5   [{'@_fa': 'true', 'affilname': 'Charles Univer...            NaN
# 6   [{'@_fa': 'true', 'affilname': 'Filozofická Fa...            NaN
# 7   [{'@_fa': 'true', 'affilname': 'Charles Univer...            NaN
# 8   [{'@_fa': 'true', 'affilname': 'Charles Univer...            NaN
# 9   [{'@_fa': 'true', 'affilname': 'Universität Ha...            NaN
#
#    prism:eIssn                                   freetoread.value  \
# 0          NaN                                                NaN
# 0          NaN                                                NaN
# 1     23524928                                                NaN
# 2     12137103                                                NaN
# 3     20796412  [{'$': 'all'}, {'$': 'publisherfullgold'}, {'$...
# ..         ...                                                ...
# 5     15526518                                                NaN
# 6     15525406                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9     15729869                                                NaN
#
#                                 freetoreadLabel.value  \
# 0                                                 NaN
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'$': 'All Open Access'}, {'$': 'Gold'}, {'$'...
# ..                                                ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
#
#                                   prism:isbn pubmed-id
# 0                                        NaN       NaN
# 0                                        NaN       NaN
# 1                                        NaN       NaN
# 2                                        NaN       NaN
# 3                                        NaN       NaN
# ..                                       ...       ...
# 5                                        NaN  25392391
# 6                                        NaN       NaN
# 7   [{'@_fa': 'true', '$': '9780387959818'}]       NaN
# 8                                        NaN       NaN
# 9                                        NaN       NaN
#
# [9630 rows x 32 columns]

# %%
df_author_ids.iloc[0]
# Out:
# @_fa                                                                   true
# link                      [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# prism:url                 https://api.elsevier.com/content/abstract/scop...
# dc:identifier                                         SCOPUS_ID:76049088350
# eid                                                      2-s2.0-76049088350
# dc:title                  Maximilianus wietrowsky SJ - His fate in the l...
# dc:creator                                                       Bočková A.
# prism:publicationName                                     Listy Filologicke
# prism:issn                                                         00244457
# prism:volume                                                            132
# prism:issueIdentifier                                                   1-2
# prism:pageRange                                                     136-165
# prism:coverDate                                                  2009-12-01
# prism:coverDisplayDate                                                 2009
# citedby-count                                                             0
# prism:aggregationType                                               Journal
# subtype                                                                  re
# subtypeDescription                                                   Review
# source-id                                                        5800222005
# openaccess                                                                0
# openaccessFlag                                                        False
# searched_authorid                                               39460994400
# timestamp                                        2022-09-08 12:32:23.127589
# prism:doi                                                               NaN
# pii                                                                     NaN
# affiliation                                                             NaN
# article-number                                                          NaN
# prism:eIssn                                                             NaN
# freetoread.value                                                        NaN
# freetoreadLabel.value                                                   NaN
# prism:isbn                                                              NaN
# pubmed-id                                                               NaN
# Name: 0, dtype: object

# %%
df_author_ids.to_csv('output/publications_author_ids.csv')

pd.Series(no_results_author_ids).to_csv('output/no_results_author_ids.csv',index=False)

# %% [markdown]
# ## Names

# %%
def request_scopus_name(firstname, surname, api_key):
    return request_scopus_search(f'auth({surname} {firstname})', api_key).assign(searched_orcid=orcid,timestamp=pd.Timestamp.now())

def search_all_names(names, api_key):
    dfs = []
    no_results = []
    for idx, row in  tqdm(names.iterrows()):
        time.sleep(.5)
        df = request_scopus_name(row.firstname,row.surname, api_key)
        if not df.empty:
            dfs.append(df)
        else:
            no_results.append(author_id)
    
    return pd.concat(dfs), no_results

# %%
names = pd.read_excel('input/list_name.xls',header=None).rename({0:'firstname',1:'surname'},axis=1)
names
# Out:
#          firstname               surname
# 0     Abdel-Mohsen          Abdel-Lattif
# 1             Adam               Konecny
# 2             Adam              Mackerle
# 3             Adam              Schrofel
# 4        Agnieszka               Bielach
# ...            ...                   ...
# 1175         Thanh              Nam Phan
# 1176          Vera       Neuzil Bunesova
# 1177      Veronika  Gvozdikova Javurkova
# 1178          Viet              Leu Quoc
# 1179        Zuzana   Sekerakova Burikova
#
# [1180 rows x 2 columns]
